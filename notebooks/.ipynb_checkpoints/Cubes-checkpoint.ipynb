# %%
def z_from_slice(slice):
    lamda0 = 1215.670
    lamda = 3470 + (slice - 1.) * 2.
    z = (lamda - lamda0) / lamda0
    
    return z

# %%
# Column names
COL_RA = "RA"
COL_DEC = "DEC"
COL_z = "z"
out_dir = "/data/hetdex/u/bgrashey/data_/"        
name = "test.fits"

from astropy.table import Table
import os
import numpy as np
from tools.EW import Measurements
from astropy.io import fits
from astropy.coordinates import SkyCoord

# catalog:
table_path = "/data/hetdex/u/bgrashey/data_/missing_mawatari_sources.fits"    
tbl = Table.read(table_path)
Catalog = tbl.to_pandas()
Catalog = Catalog.reset_index(drop=True)

directory = "/data/hetdex/u/mxhf/VDFI/VirusDeep/stackmf/ssa22_fullfp/"
file_stack = "ssa22_fullfp_stack.fits"
stack = os.path.join(directory, file_stack)
cube = fits.open(stack, memmap=True)
data = cube[0].section
header = cube[0].header

hsc_file = "/data/hetdex/u/mxhf/VDFI/joint/ssa22_hsc_pdr3_wide.fits"
with fits.open(hsc_file) as hdul:
    hsc_df = Table(hdul[1].data).to_pandas()
hsc_coords = SkyCoord(ra=hsc_df["ra"].values, 
                      dec=hsc_df["dec"].values, 
                      unit="deg", frame="icrs")        

# Neue Spalten als Listen initialisieren
new_cols = {
    "REDSHIFT": [], "EW": [], "EW_OBS": [], "EW_ERR": [],
    "FLUX": [], "FLUX_ERR": [], "CONT": [], "CONT_ERR": []
}

N = len(Catalog[COL_RA])
for n in range(N):
    print(f"\nInitialising Object {n+1}/{N}")
    
    try:
        coords = (
            Catalog[COL_RA][n],
            Catalog[COL_DEC][n],
            Catalog[COL_z][n]
        )
        
        meas = Measurements(data, header, coords, hsc_df, hsc_coords)
        EW_OBS, EW, EW_ERR, F, F_ERR, C, C_ERR, z = meas.measure_ew()
        
        new_cols["REDSHIFT"].append(z)
        new_cols["EW"].append(EW)
        new_cols["EW_OBS"].append(EW_OBS)
        new_cols["EW_ERR"].append(EW_ERR)
        new_cols["FLUX"].append(F)
        new_cols["FLUX_ERR"].append(F_ERR)
        new_cols["CONT"].append(C)
        new_cols["CONT_ERR"].append(C_ERR)
        
        print("done")
    
    except Exception as e:
        print(f"Object {n} failed: {e}")
        for key in new_cols:
            new_cols[key].append(np.nan)

# Neue Spalten an den originalen Katalog hängen
for col_name, values in new_cols.items():
    tbl[col_name] = np.array(values, dtype="f8")

# Klassifikations-Wahrscheinlichkeit berechnen
from line_classifier.probs.classification_prob import source_prob
import configparser

config_file = "/data/hetdex/u/bgrashey/notebooks/line_prob/hetdex_line_classification/tests/data/universe.cfg"
flim_file = "/data/hetdex/u/bgrashey/notebooks/Line_flux_limit_5_sigma_baseline.dat"

config = configparser.ConfigParser()
config.read(config_file)

z   = tbl["REDSHIFT"]
F   = tbl["FLUX"]
E   = tbl["FLUX_ERR"]
eq  = tbl["EW_OBS"]
eq_E = tbl["EW_ERR"]

p = source_prob(config, [1]*len(z), [1]*len(z), z, F, E, eq, eq_E,
                None, None, None, None, None, flim_file, ignore_noise=True)
tbl["PROB"] = p

out_path = os.path.join(out_dir, name)
tbl.write(out_path, overwrite=True)

cube.close()

# %%
print("done")

# %%
import numpy as np
from astropy.io import fits

with fits.open("../cubes/test.fits") as hdul:
    cube = hdul[0].data.astype(np.float32)
    header = hdul[0].header

with fits.open("../cubes/ssa22_fullfp_stack.fits") as hdul_err:
    error_cube = hdul_err[1].data.astype(np.float32)

mask = ~(error_cube > 0)

with np.errstate(divide='ignore', invalid='ignore'):
    cube /= error_cube

cube[mask] = np.nan
del error_cube, mask

hdu = fits.PrimaryHDU(cube, header=header)
hdu.writeto("../cubes/sn_cube.fits", overwrite=True)
# Out:
# WARNING: Could not memory map array with mode='readonly', falling back to mode='denywrite', which means that the array will be read-only [astropy.io.fits.file]

# %%
# %load_ext autoreload
# %autoreload 2

from tools.functions import plot_cutout_grid
from astropy.table import Table

cube = "../cubes/test.fits"
sn = "../cubes/sn_cube.fits"
missed = Table.read("../data_/injected_sources.fits")

plot_cutout_grid(
     missed,
     cube,
     "./test_cutouts.pdf",
     col_ra = "ra",
     col_dec = "dec",
     cutout_size = 20,
     num_cutouts = 10,
     use_fixed_stretch = False,      
     vmin_fixed      = -300,
     vmax_fixed      =  300,
     cmap            = "inferno",
 )
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Lade Cube: ../cubes/test.fits
#   Shape: (1036, 2478, 2260)
#   Erzeuge 10 Cutouts ...
#   Gespeichert: ./test_cutouts.pdf

# %%
def redshift_to_slice(redshift):
        lya_obs = 1216.0 * (1.0 + redshift)
        slice_ = round(1 + (lya_obs - 3470) / 2)
        return slice_

# %%
print(redshift_to_slice(2.1))
# Out:
# 151

# %%
import zarr
import numpy as np
from astropy.io import fits

def fits_ifu_to_zarr(fits_path, zarr_path, chunks=(100, 128, 128)):
    root = zarr.open_group(zarr_path, mode="w")

    with fits.open(fits_path) as hdul:
        for i, hdu in enumerate(hdul):
            if hdu.data is None:
                continue
            name = hdu.name or f"ext_{i}"
            
            # Chunks nur für 3D-Würfel anpassen, sonst auto
            c = chunks if hdu.data.ndim == 3 else "auto"
            
            arr = root.create_array(
                name,
                data=hdu.data,
                chunks=c,
                compressors=None,
            )
            arr.attrs["fits_header"] = dict(hdu.header)
            print(f"  {name}: {hdu.data.shape}, chunks={arr.chunks}")

    print(zarr.open(zarr_path).tree())

# %%
from tools.cubes import fits_ifu_to_zarr

fits_ifu_to_zarr("/data/hetdex/u/bgrashey/cubes/test.fits", "/data/hetdex/u/bgrashey/cubes/test.zarr")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from tools.cubes import fits_ifu_to_zarr
# ----> 3 fits_ifu_to_zarr("../cubes/test.fits", "../cubes/test.zarr")
#
# File /data/hetdex/u/bgrashey/notebooks/tools/cubes.py:151, in fits_ifu_to_zarr(fits_path, zarr_path, chunks)
#     148 # Chunks nur für 3D-Würfel anpassen, sonst auto
#     149 c = chunks if hdu.data.ndim == 3 else "auto"
# --> 151 arr = root.create_array(
#     152     name,
#     153     data=hdu.data,
#     154     chunks=c,
#     155     compressors=None,
#     156 )
#     157 arr.attrs["fits_header"] = dict(hdu.header)
#     158 print(f"  {name}: {hdu.data.shape}, chunks={arr.chunks}")
#
# File /data/backup/hetdex/u/bgrashey/envs/cube_aktuell/lib/python3.12/site-packages/zarr/core/group.py:2666, in Group.create_array(self, name, shape, dtype, data, chunks, shards, filters, compressors, compressor, serializer, fill_value, order, attributes, chunk_key_encoding, dimension_names, storage_options, overwrite, config, write_data)
#    2563 """Create an array within this group.
#    2564
#    2565 This method lightly wraps [zarr.core.array.create_array][].
#    (...)   2660 AsyncArray
#    2661 """
#    2662 compressors = _parse_deprecated_compressor(
#    2663     compressor, compressors, zarr_format=self.metadata.zarr_format
#    2664 )
#    2665 return Array(
# -> 2666     self._sync(
#    2667         self._async_group.create_array(
#    2668             name=name,
#    2669             shape=shape,
#    2670             dtype=dtype,
#    2671             data=data,
#    2672             chunks=chunks,
#    2673             shards=shards,
#    2674             fill_value=fill_value,
#    2675             attributes=attributes,
#    2676             chunk_key_encoding=chunk_key_encoding,
#    2677             compressors=compressors,
#    2678             serializer=serializer,
#    2679             dimension_names=dimension_names,
#    2680             order=order,
#    2681             filters=filters,
#    2682             overwrite=overwrite,
#    2683             storage_options=storage_options,
#    2684             config=config,
#    2685             write_data=write_data,
#    2686         )
#    2687     )
#    2688 )
#
# File /data/backup/hetdex/u/bgrashey/envs/cube_aktuell/lib/python3.12/site-packages/zarr/core/sync.py:203, in SyncMixin._sync(self, coroutine)
#     200 def _sync[T](self, coroutine: Coroutine[Any, Any, T]) -> T:
#     201     # TODO: refactor this to to take *args and **kwargs and pass those to the method
#     202     # this should allow us to better type the sync wrapper
# --> 203     return sync(
#     204         coroutine,
#     205         timeout=config.get("async.timeout"),
#     206     )
#
# File /data/backup/hetdex/u/bgrashey/envs/cube_aktuell/lib/python3.12/site-packages/zarr/core/sync.py:151, in sync(coro, loop, timeout)
#     147     pass
#     149 future = asyncio.run_coroutine_threadsafe(_runner(coro), loop)
# --> 151 finished, unfinished = wait([future], return_when=asyncio.ALL_COMPLETED, timeout=timeout)
#     152 if len(unfinished) > 0:
#     153     raise TimeoutError(f"Coroutine {coro} failed to finish within {timeout} s")
#
# File /data/backup/hetdex/u/bgrashey/envs/cube_aktuell/lib/python3.12/concurrent/futures/_base.py:305, in wait(fs, timeout, return_when)
#     301         return DoneAndNotDoneFutures(done, not_done)
#     303     waiter = _create_and_install_waiters(fs, return_when)
# --> 305 waiter.event.wait(timeout)
#     306 for f in fs:
#     307     with f._condition:
#
# File /data/backup/hetdex/u/bgrashey/envs/cube_aktuell/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /data/backup/hetdex/u/bgrashey/envs/cube_aktuell/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
import zarr
import dask
import dask.array as da
from astropy.wcs import WCS
from astropy.io import fits

from tools.fof_min import fof_minimal_zarr, catalog_to_wcs_table

sn_cube_path = "/data/hetdex/u/bgrashey/cubes/ssa22_fullfp_sig_filter.zarr"
fits_header_path = "/data/hetdex/u/bgrashey/cubes/ssa22_fullfp_stack.fits"
output_catalog_path = "../cubes/gefundene_quellen.fits"
sn_threshold = 0.75
linking_length = 1.5


sn_cube = da.from_zarr(sn_cube_path, read_only=True)

binary_mask = sn_cube > sn_threshold

catalog_delayed = fof_minimal_zarr(binary_mask, linking_length=linking_length)

cat_computed = dask.compute(catalog_delayed)[0]

header = fits.getheader(fits_header_path)

final_table = catalog_to_wcs_table(cat_computed, wcs_header=header)

final_table.write(output_catalog_path, overwrite=True)

print(f"Fertig: {len(final_table)} Quellen und '{output_catalog_path}' gespeichert.")
# Out:
# 1. Öffne S/N-Cube...
# 2. Generiere die Binärmaske (Thresholding)...
# 3. Erstelle FoF-Rechengraphen...
# 4. Berechne Cluster via Dask (das triggert die parallele Ausführung)...
# 5. Lade WCS-Header für Koordinaten-Transformation...
# 6. Wandle Pixeldaten in Himmelskoordinaten (RA/DEC/Wellenlänge) um...
# 7. Speichere finalen Positions-Katalog...
# Fertig! 1011857 Quellen gefunden und in '../cubes/gefundene_quellen.fits' gespeichert.

# %%
print("done")
# Out:
# done

# %%
from tools.functions import completeness_analysis

injected = "/data/hetdex/u/bgrashey/data_/injected_sources.fits"

completeness_analysis(injected, injected)

# %%
from astropy.table import Table, vstack

Table.read("/data/hetdex/u/bgrashey/data_/injected_sources_flagged.fits")
# Out:
# <Table length=10100>
#   id  chunk_index         ra         ...        flux        detected
# int64    int64         float64       ...      float64         bool
# ----- ----------- ------------------ ... ------------------ --------
#     0           1  334.3532020233734 ...  83.10818779391128     True
#     1           1 334.34489530161954 ...  55.13927522093927     True
#     2           1  334.2140558148632 ... 63.141663131455054     True
#     3           1  334.1932908157077 ...  96.70192070234545     True
#     4           1 334.21749526535154 ...  46.25790436224554     True
#     5           1  334.4558893554931 ...   93.4101038776492     True
#     6           1 334.27744361825194 ...  90.77385405384722     True
#     7           1  334.3412786235517 ...  82.90569046802624     True
#     8           1  334.3582756337231 ...  79.51410388115383     True
#   ...         ...                ... ...                ...      ...
# 10090         101 334.42101413233974 ... 10.739000734824733     True
# 10091         101 334.20374288928883 ...  35.40487245715853     True
# 10092         101  334.2246294126202 ... 43.258124404692076     True
# 10093         101  334.1686049260394 ...  64.31971266625892     True
# 10094         101 334.34316325065754 ...  8.745090039475777     True
# 10095         101  334.1973323727221 ...  27.48031986853389     True
# 10096         101 334.38445328738516 ... 24.107344846101967     True
# 10097         101  334.3225330193915 ...   4.73544358617857     True
# 10098         101   334.241657347554 ...   81.8831830476322     True
# 10099         101  334.2219273285373 ...  36.61172905654478     True
