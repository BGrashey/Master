# %%
def z_from_slice(slice):
    lamda0 = 1215.670
    lamda = 3470 + (slice - 1.) * 2.
    z = (lamda - lamda0) / lamda0
    
    return z

# %%
# Column names
COL_RA = "RA"
COL_DEC = "DEC"
COL_z = "z"
out_dir = "/data/hetdex/u/bgrashey/data_/"        
name = "test.fits"

from astropy.table import Table
import os
import numpy as np
from tools.EW import Measurements
from astropy.io import fits
from astropy.coordinates import SkyCoord

# catalog:
table_path = "/data/hetdex/u/bgrashey/data_/missing_mawatari_sources.fits"    
tbl = Table.read(table_path)
Catalog = tbl.to_pandas()
Catalog = Catalog.reset_index(drop=True)

directory = "/data/hetdex/u/mxhf/VDFI/VirusDeep/stackmf/ssa22_fullfp/"
file_stack = "ssa22_fullfp_stack.fits"
stack = os.path.join(directory, file_stack)
cube = fits.open(stack, memmap=True)
data = cube[0].section
header = cube[0].header

hsc_file = "/data/hetdex/u/mxhf/VDFI/joint/ssa22_hsc_pdr3_wide.fits"
with fits.open(hsc_file) as hdul:
    hsc_df = Table(hdul[1].data).to_pandas()
hsc_coords = SkyCoord(ra=hsc_df["ra"].values, 
                      dec=hsc_df["dec"].values, 
                      unit="deg", frame="icrs")        

# Neue Spalten als Listen initialisieren
new_cols = {
    "REDSHIFT": [], "EW": [], "EW_OBS": [], "EW_ERR": [],
    "FLUX": [], "FLUX_ERR": [], "CONT": [], "CONT_ERR": []
}

N = len(Catalog[COL_RA])
for n in range(N):
    print(f"\nInitialising Object {n+1}/{N}")
    
    try:
        coords = (
            Catalog[COL_RA][n],
            Catalog[COL_DEC][n],
            Catalog[COL_z][n]
        )
        
        meas = Measurements(data, header, coords, hsc_df, hsc_coords)
        EW_OBS, EW, EW_ERR, F, F_ERR, C, C_ERR, z = meas.measure_ew()
        
        new_cols["REDSHIFT"].append(z)
        new_cols["EW"].append(EW)
        new_cols["EW_OBS"].append(EW_OBS)
        new_cols["EW_ERR"].append(EW_ERR)
        new_cols["FLUX"].append(F)
        new_cols["FLUX_ERR"].append(F_ERR)
        new_cols["CONT"].append(C)
        new_cols["CONT_ERR"].append(C_ERR)
        
        print("done")
    
    except Exception as e:
        print(f"Object {n} failed: {e}")
        for key in new_cols:
            new_cols[key].append(np.nan)

# Neue Spalten an den originalen Katalog hängen
for col_name, values in new_cols.items():
    tbl[col_name] = np.array(values, dtype="f8")

# Klassifikations-Wahrscheinlichkeit berechnen
from line_classifier.probs.classification_prob import source_prob
import configparser

config_file = "/data/hetdex/u/bgrashey/notebooks/line_prob/hetdex_line_classification/tests/data/universe.cfg"
flim_file = "/data/hetdex/u/bgrashey/notebooks/Line_flux_limit_5_sigma_baseline.dat"

config = configparser.ConfigParser()
config.read(config_file)

z   = tbl["REDSHIFT"]
F   = tbl["FLUX"]
E   = tbl["FLUX_ERR"]
eq  = tbl["EW_OBS"]
eq_E = tbl["EW_ERR"]

p = source_prob(config, [1]*len(z), [1]*len(z), z, F, E, eq, eq_E,
                None, None, None, None, None, flim_file, ignore_noise=True)
tbl["PROB"] = p

out_path = os.path.join(out_dir, name)
tbl.write(out_path, overwrite=True)

cube.close()

# %%
print("done")

# %%
# %load_ext autoreload
# %autoreload 2

from tools.functions import plot_cutout_grid
from astropy.table import Table

cube = "/data/hetdex/u/bgrashey/cubes/test_.fits"
#sn = "/data/hetdex/u/bgrashey/cubes/sn_cube.fits"
missed = Table.read("/data/hetdex/u/bgrashey/data_/injected_sources_real.fits")
mask = missed["bin_index"] == 0
missed = missed[mask]

plot_cutout_grid(
     missed,
     cube,
     "./test_cutouts.pdf",
     col_ra = "ra",
     col_dec = "dec",
     cutout_size = 20,
     num_cutouts = 100,
     use_fixed_stretch = False,      
     vmin_fixed      = -300,
     vmax_fixed      =  300,
     cmap            = "inferno",
 )
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Lade Cube: /data/hetdex/u/bgrashey/cubes/test_.fits
#   Shape: (1036, 2478, 2260)
#   Erzeuge 100 Cutouts ...
#   Gespeichert: ./test_cutouts.pdf

# %%
def redshift_to_slice(redshift):
    lya_obs = 1215.67 * (1.0 + np.asarray(redshift, dtype=float))
    return 1 + (lya_obs - 3470.0) / 2.0  # kein round(), float

# %%
print(redshift_to_slice(2.1))
# Out:
# 151

# %%
from astropy.table import Table

cnn_scored = Table.read("/data/hetdex/u/bgrashey/data_/injected_sources_cnnscored.fits")
mask = cnn_scored["CNN_prob"] > 0.5
cnn_scored = cnn_scored[mask]
cnn_scored.write("/data/hetdex/u/bgrashey/data_/cnn_scored_sources.fits", overwrite=True)

# %%
from tools.functions import completeness_analysis, crossmatch

injected = "/data/hetdex/u/bgrashey/data_/injected_sources_real.fits"
detected = "/data/hetdex/u/bgrashey/cubes/gefundene_quellen_high_linking_length.fits"
detected_cnn = "/data/hetdex/u/bgrashey/data_/cnn/kandidaten_cube_search.fits"
injected_cnn_scored = "/data/hetdex/u/bgrashey/data_/cnn_scored_sources.fits"

#completeness_analysis(injected,
#                      detected,
#                      sky_radius=5.,
#                      dz=0.5
#                     )

matched = crossmatch(injected, injected_cnn_scored)


print("done")
# Out:
# done

# %%
import numpy as np
from astropy.table import Table
import matplotlib.pyplot as plt

cat = matched #Table.read("/data/hetdex/u/bgrashey/data_/injected_sources_flagged.fits")



#bins = [(0.05, 0.1), (0.1, 0.5), (0.5, 1), (1, 10), (10, 100),
 #       (100,1000), (1000, 2000), (2000, 10000)]

bins = [(0.001, 0.005), (0.005, 0.01), (0.1, 0.2), (0.2, 0.5), (0.5, 1.),
       (1., 2.), (2., 5.), (5., 10.), (10., 100.)]

completeness = []
flux = []

for n in range(len(bins)):
    mask = cat["bin_index"] == n
    det = cat[mask]["MATCHED"] == True
    c = det.sum() / mask.sum()
    completeness.append(c)
    flux_ = np.mean(bins[n]) 
    flux.append(flux_)

    
        
plt.plot(flux, completeness, marker="o")
plt.xscale("log")
plt.xlabel("Flux in counts")
plt.ylabel("Completeness")
plt.show()

# %%
import scipy

# %%
from astropy.table import Table

Table.read(hetdex)

from astropy.table import Table
from astropy.io import fits
from astropy.wcs import WCS
from astropy.coordinates import SkyCoord
from regions import Regions
import astropy.units as u
import numpy as np

catalog = Table.read("/data/hetdex/u/bgrashey/data_/hetdex_ssa22_laes.fits")

cube = "/data/hetdex/u/bgrashey/cubes/test.fits"
with fits.open(cube) as f:
    wcs = WCS(f[0].header).celestial

coords = SkyCoord(
    ra=catalog["RA"].data * u.deg,
    dec=catalog["DEC"].data * u.deg,
   frame="fk5"
)

regions = Regions.read("/data/hetdex/u/bgrashey/regions/fov.reg", format="ds9")

for r in regions:
    print(repr(r.meta.get("include")))

mask = np.zeros(len(coords), dtype=bool)
mask_e = np.zeros(len(coords), dtype=bool)

for r in regions:
    include = r.meta.get("include")
    if include:
        mask |= r.contains(coords, wcs)
    else:
        mask_e |= r.contains(coords, wcs)

mask_ = mask_e & mask
catalog = catalog[mask_]
catalog.write("/data/hetdex/u/bgrashey/data_/hetdex_ssa22.fits", overwrite=True)
catalog
# Out:
# 0
# 1
# WARNING: VerifyWarning: Keyword name 'TARGET_RA' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'TARGET_DEC' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'UNITS_FLUX' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# <Table length=865>
#     RA      DEC    z_hetdex ...  p_cnn         source_name          detectid
#    deg      deg             ...
#  float32  float32  float32  ... float32          bytes26             int64
# --------- -------- -------- ... ------- -------------------------- ----------
#  334.2162 0.313836    2.548 ...   0.993 HETDEX J221651.88+001849.8 4023424293
# ...

# %%
from tools.functions import crossmatch

hetdex = "/data/hetdex/u/bgrashey/data_/hetdex_ssa22.fits"
vdfi = "/data/hetdex/u/bgrashey/data_/combined_manual_vdfi_rfscored.fits"

# "/data/hetdex/u/bgrashey/data_/hetdex_sources_cnnscored.fits"

hetdex_tbl = crossmatch(hetdex, vdfi)

# %%
import matplotlib.pyplot as plt
from astropy.table import Table


detected_mask = hetdex_tbl["MATCHED"] == True
not_detected = ~detected_mask
print(f"Von uns detektierte Quellen: {detected_mask.sum()}")
print(f"Nicht detektierte Quellen: {not_detected.sum()}")
# Out:
# Von uns detektierte Quellen: 239
# Nicht detektierte Quellen: 626

# %%
plt.hist(hetdex_tbl[detected_mask]["flux_lya"], label="detected by vdfi", edgecolor="black")
plt.hist(hetdex_tbl[not_detected]["flux_lya"], color="gray", alpha=0.5, label="not detected by vdfi", edgecolor="black")
plt.xlabel("Lyman alpha fluss")
plt.legend()
plt.show()

plt.hist(hetdex_tbl[detected_mask]["z_hetdex"], label="detected by vdfi", edgecolor="black")
plt.hist(hetdex_tbl[not_detected]["z_hetdex"], color="gray", alpha=0.5, label="not detected by vdfi", edgecolor="black")
plt.xlabel("Redshift")
plt.legend()
plt.show()

# %%
# %load_ext autoreload
# %autoreload 2

from tools.functions import plot_cutout_grid
from astropy.table import Table

cube = "/data/hetdex/u/bgrashey/cubes/sn_cube.fits"
missed = hetdex_tbl[not_detected]

plot_cutout_grid(
     missed,
     cube,
     "./hetdex_cutouts.pdf",
     col_ra = "RA",
     col_dec = "DEC",
     col_z = "z_hetdex",
     cutout_size = 40,
     num_cutouts = 25,
     use_fixed_stretch = False,      
     vmin_fixed      = -1,
     vmax_fixed      =  2,
     cmap            = "gray",
 )
# Out:
# Lade Cube: /data/hetdex/u/bgrashey/cubes/sn_cube.fits
#   Shape: (1036, 2478, 2260)
#   Erzeuge 25 Cutouts ...
#   Gespeichert: ./hetdex_cutouts.pdf

# %%
from astropy.table import Table
import matplotlib.pyplot as plt

cnn_scored = Table.read("/data/hetdex/u/bgrashey/data_/hetdex_sources_cnnscored.fits")
mask = cnn_scored["CNN_prob"] > 0.5

plt.hist(cnn_scored[mask]["flux_lya"], label="CNN scored > 0.5", edgecolor="black")
plt.hist(hetdex_tbl[detected_mask]["flux_lya"], label="detected by vdfi", edgecolor="black",
         color="gray", alpha=0.5)
plt.xlabel("LYA Fluss [counts]")
plt.legend()
plt.show()
