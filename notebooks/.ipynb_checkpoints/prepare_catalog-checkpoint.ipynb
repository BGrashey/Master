# %%
# ! /data/u/bgrashey/micromamba remove -p /data/backup/hetdex/u/bgrashey/envs/cube_aktuell astropy --yes

# %%
import numpy as np
import matplotlib.pyplot as plt

from astropy.table import Table
from astropy.cosmology import Planck18 as cosmo
import astropy.units as u

from tools.functions import (completeness_function,
                             radec_z_to_cartesian,
                             knn_density
                            )

# %%
catalog_path = "/data/hetdex/u/bgrashey/data_/full_catalog.fits"
cat = Table.read(catalog_path)

# %%
#cat

# %% [markdown]
# # Add the completeness to each catalog source

# %%
Flux = np.asanyarray(cat["FLUX"]) / 1e-17

popt = np.array([0.43107471, 0.53873367, 2.32606927, 0.50485321])

cat["COMPLETENESS"] = completeness_function(Flux, *popt)

# %% [markdown]
# # Add the Luminosity to eah catalog source

# %%
Flux = np.asanyarray(cat["FLUX"])  # 10 für W/m^2
z = np.asanyarray(cat["REDSHIFT"])

def luminosity(F, z):
    D_L = cosmo.luminosity_distance(z).to(u.cm)
    L = 4 * np.pi * D_L**2 * F
    return L.value

cat["LUMINOSITY"] = luminosity(Flux, z)
# Out:
# /data/backup/hetdex/u/bgrashey/envs/cube_aktuell/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:2625: RuntimeWarning: invalid value encountered in _integral_comoving_distance_z1z2_scalar (vectorized)
#   outputs = ufunc(*args, out=...)

# %% [markdown]
# # Add the local density to each source

# %%
pos = radec_z_to_cartesian(cat["ra_vdfi"], cat["dec_vdfi"], cat["z_vdfi"])
rho, _ = knn_density(pos)

cat["DENSITY"] = rho

# %% [markdown]
# # Inspect the catalog

# %%
print(cat.columns)
# Out:
# <TableColumns names=('id_vdfi','nspaxels_vdfi','xmin_vdfi','xmax_vdfi','ymin_vdfi','ymax_vdfi','zmin_vdfi','zmax_vdfi','summed_flux_vdfi','xwm_vdfi','ywm_vdfi','zwm_vdfi','xsigma_vdfi','ysigma_vdfi','zsigma_vdfi','max_flux_vdfi','max_SN_vdfi','ra_vdfi','dec_vdfi','wlwm_vdfi','world_xmin_vdfi','world_ymin_vdfi','world_zmin_vdfi','world_xmax_vdfi','world_ymax_vdfi','world_zmax_vdfi','psfit_success_vdfi','psfit_A_vdfi','psfit_x0_vdfi','psfit_y0_vdfi','psfit_z0_vdfi','psfit_x_vdfi','psfit_y_vdfi','psfit_z_vdfi','psfit_sigma_xy_vdfi','psfit_e_vdfi','psfit_theta_vdfi','psfit_sigma_z_vdfi','psfit_C_vdfi','psfit_flux_model_vdfi','psfit_chi2_vdfi','psfit_chi2_red_vdfi','psfit_ndof_vdfi','psfit_n_pix_vdfi','psfit_err_A_vdfi','psfit_err_x0_vdfi','psfit_err_y0_vdfi','psfit_err_z0_vdfi','psfit_err_sigma_xy_vdfi','psfit_err_e_vdfi','psfit_err_theta_vdfi','psfit_err_sigma_z_vdfi','psfit_err_C_vdfi','z_vdfi','object_id_hsc','object_id_isnull_hsc','ra_hsc','ra_isnull_hsc','dec_hsc','dec_isnull_hsc','g_cmodel_mag_hsc','g_cmodel_mag_isnull_hsc','g_cmodel_magerr_hsc','g_cmodel_magerr_isnull_hsc','g_cmodel_flux_hsc','g_cmodel_flux_isnull_hsc','g_cmodel_fluxerr_hsc','g_cmodel_fluxerr_isnull_hsc','sep_arcsec','EQW_obs','EQW_rest','EQW_obs_psf','EQW_rest_psf','bad_region','P_of_LAE','P_of_LAE_psf','psfit_ra_vdfi','psfit_dec_vdfi','psfit_redshift_vdfi','gaussian_local_density','x_pix_manual','y_pix_manual','z_pix_manual','ra_manual','dec_manual','z_manual','sep_arcsec_manual','dz_manual','rel_dz_manual','manually_detected','CNN_prob','rf_score','rf_selected','REDSHIFT','EW','EW_OBS','EW_ERR','FLUX','FLUX_ERR','CONT','CONT_ERR','PROB','COMPLETENESS','LUMINOSITY','DENSITY')>

# %%
LAE_mask = cat["PROB"] > 0.5
cat = cat[LAE_mask]
cat.sort("FLUX", reverse=True)

# %%
zmin = 3.
zmax = 3.2
z_mask = (cat["REDSHIFT"] > zmin) & (cat["REDSHIFT"] < zmax)
cat = cat[z_mask]
redshift_bins = np.linspace(zmin, zmax, 15)

plt.hist(cat["REDSHIFT"], bins=redshift_bins, edgecolor="black")
plt.xlabel("z")
plt.ylabel("N")
plt.show()

# %%
prob_bins = np.linspace(0,1,11)
plt.hist(cat["PROB"], bins=prob_bins, edgecolor="black")
plt.xlabel("P(LAE)")
plt.ylabel("N")
plt.show()

# %% [markdown]
# # Inspect the LAE catalog with narrow band images

# %%
from tools.functions import plot_cutout_grid

plot_cutout_grid(
    catalog=cat,
    cube_file="/data/hetdex/u/bgrashey/cubes/ssa22_fullfp_stack.fits",
    output_file="./nb_images.pdf",
    num_cutouts=5,
    num_wave_slices=10,
    cmap="inferno"
)
# Out:
# Lade Cube: /data/hetdex/u/bgrashey/cubes/ssa22_fullfp_stack.fits
#   Shape: (1036, 2478, 2260)
#   Erzeuge 5 Cutouts ...
#   Gespeichert: ./nb_images.pdf

# %%
cat.write("./lae_temp.fits", overwrite=True)

# %%
from tools.functions import luminosity_function as lf
import matplotlib.pyplot as plt
lim = 3.162e-01 * 1e-17

lum_low = 41
lum_high = 45

bin_edges = np.logspace(lum_low, lum_high, 7)

bins, phi, n_gal = lf(lim, "./lae_temp.fits", bin_edges)

# %%
valid = n_gal > 3
invalid = ~valid

# %%
plt.scatter(bins[valid], phi[valid])
plt.scatter(bins[invalid], phi[invalid], color="r")
plt.xscale("log")
plt.yscale("log")
plt.xlabel("L [erg/s]")
plt.ylabel(r"$\Phi$ [$\Delta$log(L)$^{-1}$ Mpc$^{-3}$]")
#plt.xlim(1e40, 1e46)
plt.show()

# %%
valid = np.isfinite(phi)

log_edges = np.log10(bin_edges)
delta_log_lum = np.diff(log_edges)

phi_per_bin = np.where(valid, phi * delta_log_lum, 0.0)
cummulative = np.cumsum(phi_per_bin[::-1])[::-1]

plt.scatter(bins, cummulative)
plt.xscale("log")
plt.yscale("log")
plt.ylabel(r">L [Mpc$^{-3}$]")
plt.xlabel("L [erg s$^{-1}$]")
plt.show()
