# %%
#! /data/u/bgrashey/micromamba install -p /data/backup/hetdex/u/bgrashey/envs/cube_aktuell mpmath --yes

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt

from astropy.table import Table
from astropy.cosmology import Planck18 as cosmo
import astropy.units as u

from tools.functions import (completeness_function,
                             radec_z_to_cartesian,
                             knn_density
                            )

# %%
catalog_path = "/data/hetdex/u/bgrashey/data_/full_catalog.fits"
cat = Table.read(catalog_path)

# %%
#cat

# %% [markdown]
# # Add the completeness to each catalog source

# %%
Flux = np.asanyarray(cat["FLUX"]) / 1e-17

popt = np.array([0.43107471, 0.53873367, 2.32606927, 0.50485321])

cat["COMPLETENESS"] = completeness_function(Flux, *popt)

# %% [markdown]
# # Add the Luminosity to eah catalog source

# %%
Flux = np.asanyarray(cat["FLUX"])  # 10 für W/m^2
z = np.asanyarray(cat["REDSHIFT"])

def luminosity(F, z):
    D_L = cosmo.luminosity_distance(z).to(u.cm)
    L = 4 * np.pi * D_L**2 * F
    return L.value

cat["LUMINOSITY"] = luminosity(Flux, z)
# Out:
# /data/backup/hetdex/u/bgrashey/envs/cube_aktuell/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:2625: RuntimeWarning: invalid value encountered in _integral_comoving_distance_z1z2_scalar (vectorized)
#   outputs = ufunc(*args, out=...)

# %% [markdown]
# # Add the local density to each source

# %%
pos = radec_z_to_cartesian(cat["ra_vdfi"], cat["dec_vdfi"], cat["z_vdfi"])
rho, _ = knn_density(pos)

cat["DENSITY"] = rho

# %% [markdown]
# # Inspect the catalog

# %%
#print(cat.columns)

# %%
LAE_mask = cat["PROB"] > 0.5
cat_lae = cat[LAE_mask]
cat_lae.sort("FLUX", reverse=True)

# %%
zmin = 2.3
zmax = 3.6
z_mask = (cat_lae["REDSHIFT"] > zmin) & (cat_lae["REDSHIFT"] < zmax)
cat_z = cat_lae[z_mask]
redshift_bins = np.linspace(zmin, zmax, 9)

plt.hist(cat_z["REDSHIFT"], bins=redshift_bins, edgecolor="black")
plt.xlabel("z")
plt.ylabel("N")
plt.show()

# %%
prob_bins = np.linspace(0,1,11)
plt.hist(cat_z["PROB"], bins=prob_bins, edgecolor="black")
plt.xlabel("P(LAE)")
plt.ylabel("N")
plt.show()

# %% [markdown]
# # Inspect the LAE catalog with narrow band images

# %%
from tools.functions import plot_cutout_grid

plot_cutout_grid(
    catalog=cat_z,
    cube_file="/data/hetdex/u/bgrashey/cubes/ssa22_fullfp_stack.fits",
    output_file="./nb_images.pdf",
    num_cutouts=5,
    num_wave_slices=10,
    cmap="inferno",
    use_fixed_stretch=True,
    vmax_fixed=0.005,
    vmin_fixed=-0.005
)
# Out:
# Lade Cube: /data/hetdex/u/bgrashey/cubes/ssa22_fullfp_stack.fits
#   Shape: (1036, 2478, 2260)
#   Erzeuge 5 Cutouts ...
#   Gespeichert: ./nb_images.pdf

# %%
cat_z.write("./lae_temp.fits", overwrite=True)

# %%
from tools.functions import luminosity_function as lf
import matplotlib.pyplot as plt
lim = 1e-17 #3.162e-01 * 1e-17

lum_low = 41
lum_high = 44

bin_edges = np.logspace(lum_low, lum_high, 11)

#bin_edges = np.array([
#    1.00e+41,
#    1.00e+42,   
#    2.00e+42,
#    3.00e+42,
#    5.00e+42,   
#    8.00e+42,
#    1.30e+43,
#    2.00e+43,
#    4.00e+43,   
#    9.00e+43,
#    1.00e+47,   
#])


bins, phi, n_gal = lf(lim, "./lae_temp.fits", bin_edges)

# %%
valid = n_gal > 3
invalid = ~valid
print(n_gal)
print(sum(n_gal))
# Out:
# [  0   3  52 320 605 473 180  36  17   5]
# 1691

# %%
#plt.scatter(bins[valid], phi[valid])
#plt.scatter(bins[invalid], phi[invalid], color="r")
#plt.xscale("log")
#plt.yscale("log")
#plt.xlabel("L [erg/s]")
#plt.ylabel(r"$\Phi$ [$\Delta$log(L)$^{-1}$ Mpc$^{-3}$]")
#plt.xlim(1e40, 1e46)
#plt.show()

# %%
from tools.schechter_mass_function import fit_schechter, corner_plot, schechter_log

phi_err = phi * 0.1

results = fit_schechter(bins[valid], phi[valid], phi_err[valid])
fig = corner_plot(results)
plt.show()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5000/5000 [00:08<00:00, 607.54it/s]

# %%
Phi_ = schechter_log(bins, results["log_phistar"][0], results["log_Lstar"][0],
                    results["alpha"][0])

plt.errorbar(bins[valid], phi[valid], yerr=phi_err[valid], fmt="o")
plt.plot(bins, Phi_)

plt.xscale("log")
plt.yscale("log")
plt.xlabel("L [erg/s]")
plt.ylabel(r"$\Phi$ [$\Delta$log(L)$^{-1}$ Mpc$^{-3}$]")
plt.show()

# %%
# cummulative mass function

from tools.schechter_mass_function import cum_test

valid = np.isfinite(phi)

log_edges = np.log10(bin_edges)
delta_log_lum = np.diff(log_edges)

phi_per_bin = np.where(valid, phi * delta_log_lum, 0.0)
cummulative = np.cumsum(phi_per_bin[::-1])[::-1]

phi_cum = cum_test(bins, results["log_phistar"][0], results["log_Lstar"][0],
                    results["alpha"][0])

plt.scatter(bins, cummulative)
plt.plot(bins, phi_cum)
plt.xscale("log")
plt.yscale("log")
plt.ylabel(r">L [Mpc$^{-3}$]")
plt.xlabel("L [erg s$^{-1}$]")
plt.show()
